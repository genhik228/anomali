# %%
import pandas as pd
data = pd.read_csv("antifraud_analyst_test.csv")
data
# Out:
#       Unnamed: 0                           user_id  ip_address_int  \
# 0           3366  198ad8fccf972870c82440ccc63edf49      2966871082
# 1           2803  ca2e7fe913a25587041b8c6c5e60ea0f      1297308922
# 2            326  8f150a0a71537e08d35614d213b7bdd7      1578740140
# 3            600  cf073bf0448ad5a1986df247b1cba4df      3267270729
# 4           2769  00bd782285899d87e15c9cf7514be582      1438660704
# ...          ...                               ...             ...
# 8628        5153  34f9542c9f7b9d41835a2373ba523f40      1578741496
# 8629        1735  a391728ddad74b7c9dc2e7d2d63a1dc1      3647700988
# 8630         580  cfff67ff60676aeeed6b9f479513e4d2      2997921807
# 8631        1653  f227f15e4ee0467b7088710334ffdef9      1438660769
# 8632        4664  57e824def22ae02fea5687b06fa3fb5d       531493163
#
#       click_timestamp                            source  \
# 0          1635794564  7963a20082129fc1f2d1cf77e23d05cf
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  ip_address_int  click_timestamp
# count  8633.000000    8.633000e+03     8.633000e+03
# mean   2175.664659    1.968633e+09     1.635759e+09
# std    1422.733698    9.739459e+08     2.404149e+04
# min       0.000000    3.683916e+07     1.635714e+09
# 25%     977.000000    1.373552e+09     1.635741e+09
# 50%    2056.000000    1.546060e+09     1.635760e+09
# 75%    3135.000000    2.990785e+09     1.635779e+09
# max    5214.000000    3.653757e+09     1.635800e+09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8633 entries, 0 to 8632
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       8633 non-null   int64
#  1   user_id          8633 non-null   object
#  2   ip_address_int   8633 non-null   int64
#  3   click_timestamp  8633 non-null   int64
#  4   source           8633 non-null   object
#  5   sub_source       8633 non-null   object
#  6   sub_source_2     8633 non-null   object
#  7   sub_source_3     8633 non-null   object
#  8   referer          8633 non-null   object
#  9   fingerprint      8633 non-null   object
#  10  ua               3739 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 742.0+ KB

# %%
data['user_id'].value_counts()
# Out:
# b3f7233aa1812ba3241595ba24623504    12
# a1867661189878cbc0f6e2a3139b5dd5    11
# 371370ec7e273ec0a12ad91601a877b6    11
# 4391ca69eb0e93c6752125f785fa8ef6    10
# b49e0964e2ee594a380ff8f702df3e0b    10
#                                     ..
# c2b6074729def99a889d68e431e82728     1
# 8ddc1e8824d506c500135ac1071fb9ec     1
# 4ad08d754710f6f80bbf2213e3dbf7e9     1
# b0ecc2fb9c6fbdccd6c154bf3692c63c     1
# 5143b6e5d9b6ceb76b791b1739bcd84b     1
# Name: user_id, Length: 7422, dtype: int64

# %%
data[data['ip_address_int']== 3286945894].value_counts()
# Out:
# 3286945894    299
# 1297308922    287
# 1546059692    265
# 1438660769    253
# 3267270763    251
#              ...
# 1596853361      1
# 2956706437      1
# 528841354       1
# 1435239053      1
# 3169353728      1
# Name: ip_address_int, Length: 5171, dtype: int64

# %%
data['ua'].value_counts()
# Out:
# axios/0.23.0                                                                                                                                                               1940
# axios/0.22.0                                                                                                                                                               1059
# Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/95.0.4638.69 Safari/537.36                                                            197
# axios/0.24.0                                                                                                                                                                196
# Mozilla/5.0 (compatible; AdBot/1.0)                                                                                                                                           9
# ...

# %%
data[data['user_id'] == 'b3f7233aa1812ba3241595ba24623504']
# Out:
#       Unnamed: 0                           user_id  ip_address_int  \
# 131          575  b3f7233aa1812ba3241595ba24623504      3286945894
# 1313         572  b3f7233aa1812ba3241595ba24623504      3286945894
# 1493         573  b3f7233aa1812ba3241595ba24623504      3286945894
# 1513         577  b3f7233aa1812ba3241595ba24623504      3286945894
# 3887         588  b3f7233aa1812ba3241595ba24623504      3286945894
# 4454         567  b3f7233aa1812ba3241595ba24623504      3286945894
# 4514         571  b3f7233aa1812ba3241595ba24623504      3286945894
# 4593         576  b3f7233aa1812ba3241595ba24623504      3286945894
# 5225         568  b3f7233aa1812ba3241595ba24623504      3286945894
# 6456         569  b3f7233aa1812ba3241595ba24623504      3286945894
# 7266         570  b3f7233aa1812ba3241595ba24623504      3286945894
# 7637         574  b3f7233aa1812ba3241595ba24623504      3286945894
#
#       click_timestamp                            source  \
# ...

# %%
# axios/0.22.0 - 
# маска сети
# шлюз
# маршутизатор, роутер
# адрес сети, ip address
# sha256, md5 - РАСХЭШИРОВАТЬ
# HeadlessChrome + Selenium (50/50)
# Mozilla/5.0 (compatible; AdBot/1.0)
# Proxy + VPN + TOR

# Очень активные пользователи
# Очень активные IP-address
# Заходит ночью??

# sub_source и referer - одинаковые
# Добавить колонку anomali: boolean
# kaggle.com

# %%
# data.loc[0]
# data.loc[8632]
# Out:
# Unnamed: 0                                     3366
# user_id            198ad8fccf972870c82440ccc63edf49
# ip_address_int                           2966871082
# click_timestamp                          1635794564
# source             7963a20082129fc1f2d1cf77e23d05cf
# sub_source         fba462c8894f1111b7efb1c67a094cf3
# sub_source_2       3eade3c2ce6ed1216d1b40ae2c1bd2ae
# sub_source_3       fba462c8894f1111b7efb1c67a094cf3
# referer            51c5abc39206cf32e996ee04d30668cc
# fingerprint        bab3ec9ff6cf23ecdc02842d959c6c10
# ua                                              NaN
# Name: 0, dtype: object

# %%
data.loc[data.ua.str.contains("Bot",na=False)]
# ua - это столбец
# loc - индекс
# Out:
#       Unnamed: 0                           user_id  ip_address_int  \
# 240         3623  d1d65e9e134a0f8b75f2a3d0a593947c      1441325442
# 1689        1439  7b5a28d049e117a9ee7d508698ff2b9a      1441325442
# 2283        2122  342582f6fca440c4041c7efc1cf4e24b      1441325442
# 3500        3337  dd592d7e22b3706d3198a0bf43c217e3      1441325442
# 4299        2450  36edadd5e970625413d5efcafdee9ddc      1441325442
# 5077        2451  36edadd5e970625413d5efcafdee9ddc      1441325442
# 7993        1440  7b5a28d049e117a9ee7d508698ff2b9a      1441325442
# 8563        3222  dd592d7e22b3706d3198a0bf43c217e3      1441325442
# 8627        4210  342582f6fca440c4041c7efc1cf4e24b      1441325442
#
#       click_timestamp                            source  \
# 240        1635769316  b8ff9dd3c08df3421a7351301e953d56
# 1689       1635767554  237a3819d4bb794f10a1ff63527aea4e
# 2283       1635745057  237a3819d4bb794f10a1ff63527aea4e
# 3500       1635750605  e916a8afcc976db70adb0eb988eedd2a
# ...

# %%
import time
unix_timestamp  = int(1635779485)
utc_time = time.gmtime(unix_timestamp)
local_time = time.localtime(unix_timestamp)
print(time.strftime("%Y-%m-%d %H:%M:%S", local_time))
# Out:
# 2021-11-01 18:11:25

# %%
data['ip_address_int'].plot(kind='box')
plt.show()

# %%
data.groupby(['ip_address_int']).size().plot()
plt.show()
# очень много заходов с 1 ip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-18a03d92df9b> in <module>
#       1 data.groupby(['ip_address_int']).size().plot()
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
obj_df = data.select_dtypes(include=['object']).copy()
obj_df[obj_df.isnull().any(axis=1)]
# Out:
#                                user_id                            source  \
# 0     198ad8fccf972870c82440ccc63edf49  7963a20082129fc1f2d1cf77e23d05cf
# 2     8f150a0a71537e08d35614d213b7bdd7  aec15b6423f1ce2204c44e4c1c88a49d
# 5     4cb0627e37a18eb437a924e847386d9c  2936929714756ae59d1309da8b7b7012
# 6     7df930004f439775e7f9b9538c43a964  2936929714756ae59d1309da8b7b7012
# 8     a0fa65474952f586d1957c74436849bb  64bc492dab81c45d6d83be527f49f963
# ...                                ...                               ...
# 8625  ef81d73cde80e1d2bbf3f60242f4e9da  9d882d78bf1156a8e7bd5e734305e914
# 8628  34f9542c9f7b9d41835a2373ba523f40  aec15b6423f1ce2204c44e4c1c88a49d
# 8629  a391728ddad74b7c9dc2e7d2d63a1dc1  4af912c1ee86d38c5f33bf0cfe679325
# 8630  cfff67ff60676aeeed6b9f479513e4d2  1f107ae75f44d807e5e40ba16688ea95
# 8632  57e824def22ae02fea5687b06fa3fb5d  b16ae914063900219728933067a895c5
#
#                             sub_source                      sub_source_2  \
# ...

# %%
categorical = list(data.dtypes[data.dtypes == "object"].index)
data[categorical] = data[categorical].fillna("NotGiven")
data[categorical].sample(5)
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSE = %.4f" % rmse(y_test, y_pred))
# Out:
#                                user_id                            source  \
# 4786  6b8867713127a885dbd8d94dd537a61f  250820642ba26fc02d946cf504440fdf
# 6702  733a5b6d7a9dc83c13b0d4834b518e37  5d1b41825a5dbe6b588ab93c77bb9bc5
# 4041  e0c86b7daa9969202e163ab7063e6d0b  8bbec791c483d01a6e51c5bc4d8212bf
# 2725  2323bda5014ebf09107ef29e13a8ab0d  aec15b6423f1ce2204c44e4c1c88a49d
# 2119  95d7638f2c4f289b815a098be2ac8326  aec15b6423f1ce2204c44e4c1c88a49d
#
#                             sub_source                      sub_source_2  \
# 4786  fba462c8894f1111b7efb1c67a094cf3  7791ccbd2270c2d91531262715bad131
# 6702  fba462c8894f1111b7efb1c67a094cf3  7791ccbd2270c2d91531262715bad131
# 4041  fba462c8894f1111b7efb1c67a094cf3  333403cebe4ed73b323d8f42656d2fe6
# 2725  fba462c8894f1111b7efb1c67a094cf3  a1d1ec2365378c2e69e3c48417141bd0
# 2119  fba462c8894f1111b7efb1c67a094cf3  a1d1ec2365378c2e69e3c48417141bd0
#
#                           sub_source_3                           referer  \
# ...

# %%
data['anomaliy'] = False
data['anomaliy']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8628    False
# 8629    False
# 8630    False
# 8631    False
# 8632    False
# Name: anomaliy, Length: 8633, dtype: bool

# %%
data.loc[data.ua.str.contains("AdBot", na=False), 'anomaliy'] = True
# adbot = data[data['anomaliy'] == 1 ]
# adbot
data["anomaliy"].value_counts(normalize=True)
# Out:
# False    0.998957
# True     0.001043
# Name: anomaliy, dtype: float64

# %%
import time
for times in list(adbot['click_timestamp']):
    unix_timestamp  = int(times)
    utc_time = time.gmtime(unix_timestamp)
    local_time = time.localtime(unix_timestamp)
    print(time.strftime("%Y-%m-%d %H:%M:%S", local_time))
# Out:
# 2021-11-01 15:21:56
# 2021-11-01 14:52:34
# 2021-11-01 08:37:37
# 2021-11-01 10:10:05
# 2021-11-01 07:22:56
# 2021-11-01 07:22:58
# 2021-11-01 14:52:35
# 2021-11-01 13:34:04
# 2021-11-01 15:47:05

# %%
data.loc[data.ua.str.contains("HeadlessChrome", na=False), 'anomaliy'] = True
# HeadlessChrome = data[data['anomaliy'] == 1 ]
data["anomaliy"].value_counts(normalize=True)
# Out:
# False    0.975443
# True     0.024557
# Name: anomaliy, dtype: float64

# %%
import matplotlib.pyplot as plt
data['Unnamed: 0'].plot(kind='box')
plt.show()

# %%
ip_most = data.groupby(['ip_address_int']).size().to_dict() # dict
# {'key':'value'}
# [1,4,4,5]
ip_most = [key for key,value in ip_most.items() if value > 1] # list
print(len(ip_most))
data.loc[data.ip_address_int.isin(ip_most), 'anomaliy'] = True
data["anomaliy"].value_counts(normalize=True)
# Out:
# 180
# False    0.574192
# True     0.425808
# Name: anomaliy, dtype: float64

# %%
anomaliy = data[data['anomaliy'] == True]
anomaliy.to_csv("Anomaliy.csv", index=False)

# %%
data.loc[data.source == data.referer, 'anomaliy'] = True
data.loc[data.sub_source == data.referer, 'anomaliy'] = True
data.loc[data.sub_source_2 == data.referer, 'anomaliy'] = True
data.loc[data.sub_source_3 == data.referer, 'anomaliy'] = True
data["anomaliy"].value_counts(normalize=True)
# Out:
# False    0.574192
# True     0.425808
# Name: anomaliy, dtype: float64
